# %%
import pandas as pd

# %%
df = pd.read_csv('fuel_ferc1.csv')

# %%
df.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
A = [1,2,3,4,5,6]
B = [13, 21, 34]

# %%
print(A.extend(B))
# Out:
# None

# %%
A+B
# Out:
# [1, 2, 3, 4, 5, 6, [13, 21, 34], [13, 21, 34], 13, 21, 34, 13, 21, 34]

# %%
np.identity(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
import numpy as np

# %%
np.eye(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %% [markdown]
# ### Which of the following fuel type code has the lowest average fuel cost per unit burned?

# %%
df.groupby("fuel_type_code_pudl").mean()["fuel_cost_per_unit_burned"].sort_values()
# Out:
# fuel_type_code_pudl
# gas          13.659397
# other        18.253856
# waste        19.518122
# coal         67.421830
# oil         168.877086
# nuclear    4955.157002
# Name: fuel_cost_per_unit_burned, dtype: float64

# %% [markdown]
# ### What is the standard deviation and 75th percentile of the measure of energy per unit (Fuel_mmbtu_per_unit) in two decimal places?

# %%
df.describe()
# Out:
#        utility_id_ferc1   report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count      29523.000000  29523.000000     2.952300e+04         29523.000000
# mean         118.601836   2005.806050     2.622119e+06             8.492111
# std           74.178353      7.025483     9.118004e+06            10.600220
# min            1.000000   1994.000000     1.000000e+00             0.000001
# 25%           55.000000   2000.000000     1.381700e+04             1.024000
# 50%          122.000000   2006.000000     2.533220e+05             5.762694
# 75%          176.000000   2012.000000     1.424034e+06            17.006000
# max          514.000000   2018.000000     5.558942e+08           341.260000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count               29523.000000                  2.952300e+04
# mean                  208.649031                  9.175704e+02
# std                  2854.490090                  6.877593e+04
# ...

# %% [markdown]
# ### What is the skewness and kurtosis for the fuel quantity burned in two decimal places?

# %%
df['fuel_qty_burned'].skew()
# Out:
# 15.851495469109503

# %%
df['fuel_qty_burned'].kurtosis()
# Out:
# 651.3694501337732

# %% [markdown]
# ### Which feature has missing values and what is the total number of missing value and percentage of the missing rows as a factor of the total number of rows in three decimal places?
#
# (Enter answer in the format: Feature: xxx, Total: xxx, Percent: xxx)

# %%
df.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
df.shape
# Out:
# (29523, 11)

# %%
(180/29523)*100
# Out:
# 0.609694136774718

# %% [markdown]
# - Feature with missing value is: "fuel_unit",
# - Total number of missing value is: 180,
# - Percentage of missing rows is: 0.610

# %% [markdown]
# ### The feature with missing values falls under what category? What missing value imputation technique would you use?

# %%
df.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %% [markdown]
# ### Which of the features has the second and third lowest correlation with the Fuel Cost Per Unit Burned?

# %%
df.corr().sort_values("fuel_cost_per_unit_burned", ascending=True)
# Out:
#                               utility_id_ferc1  report_year  fuel_qty_burned  \
# utility_id_ferc1                      1.000000     0.093323        -0.057447
# fuel_qty_burned                      -0.057447     0.012952         1.000000
# fuel_mmbtu_per_unit                  -0.066946    -0.110853        -0.080946
# fuel_cost_per_mmbtu                   0.006122     0.010261        -0.001896
# fuel_cost_per_unit_delivered         -0.016414    -0.014043        -0.003551
# report_year                           0.093323     1.000000         0.012952
# fuel_cost_per_unit_burned            -0.037863     0.013599        -0.018535
#
#                               fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# utility_id_ferc1                        -0.066946                  -0.037863
# fuel_qty_burned                         -0.080946                  -0.018535
# fuel_mmbtu_per_unit                      1.000000                  -0.010034
# ...

# %% [markdown]
# ### For the fuel type coal, what is the percentage change in the fuel cost per unit burned in 1998 compared to 1994?

# %%
df[df['fuel_type_code_pudl'] == 'coal'].groupby("report_year").sum()['fuel_cost_per_unit_burned']
# Out:
# report_year
# 1994     14984.572
# 1995     14571.785
# 1996     12694.803
# 1997     43742.178
# 1998     11902.597
# 1999     16303.468
# 2000    100428.831
# 2001     15109.012
# 2002      9171.164
# 2003     30954.110
# 2004      9632.063
# 2005     11107.182
# 2006     12402.684
# 2007     12965.171
# 2008     14331.348
# 2009     45554.858
# 2010     88627.745
# 2011     17001.015
# 2012     17546.097
# 2013     17629.860
# 2014     15412.197
# 2015     13338.235
# 2016     11100.925
# 2017     10254.284
# 2018      9488.197
# Name: fuel_cost_per_unit_burned, dtype: float64

# %% [markdown]
# ### Which year has the highest average fuel cost per unit delivered?

# %%
df.groupby('report_year').sum().sort_values("fuel_cost_per_unit_delivered", ascending=False)
# Out:
#              utility_id_ferc1  fuel_qty_burned  fuel_mmbtu_per_unit  \
# report_year
# 1997                   118553     3.077973e+09         11210.909740
# 1996                   118281     2.768693e+09         11726.508078
# 2000                   152518     3.394100e+09         12665.204661
# 2009                   144366     2.633401e+09          9394.970149
# 2018                   127120     3.974124e+09          6273.315699
# 2015                   140551     3.650763e+09          7889.076813
# 1998                   121599     3.617070e+09         11850.394701
# 2014                   151368     3.161710e+09          8885.938884
# 2013                   146377     3.287065e+09          9348.631876
# 2004                   144379     2.124797e+09          9932.250643
# 2010                   148789     3.056312e+09          9552.091071
# 2016                   137643     3.818861e+09          7079.257780
# 2001                   153935     3.147821e+09         11351.712598
# ...
